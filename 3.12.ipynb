# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
data = np.arange(60)
plt.plot(data)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(3, 3, 1)

# %%
ax1.hist(np.random.randn(100), bins=20, color='k',alpha=0.3)
# Out:
# (array([ 3.,  4.,  2.,  1.,  9., 13., 11., 12.,  4.,  9.,  5.,  5.,  7.,
#          5.,  2.,  3.,  1.,  1.,  1.,  2.]),
#  array([-1.98879587, -1.75244549, -1.51609511, -1.27974472, -1.04339434,
#         -0.80704396, -0.57069358, -0.33434319, -0.09799281,  0.13835757,
#          0.37470795,  0.61105834,  0.84740872,  1.0837591 ,  1.32010948,
#          1.55645987,  1.79281025,  2.02916063,  2.26551102,  2.5018614 ,
#          2.73821178]),
#  <a list of 20 Patch objects>)

# %%
from numpy.random import randn
plt.plot(randn(30).cumsum(), 'k--')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
from numpy.random import randn
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')

# %%
ax.legend(loc='best')

# %%
import pandas as pd
s = pd.Series(np.random.randn(10).cumsum(),index=np.arange(0, 150, 10))
s.plot()

# %%
import pandas as pd
s = pd.Series(np.random.randn(10).cumsum(),index=np.arange(0, 100, 10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),columns=['x', 'y', 'z', 'w'],index=np.arange(0, 100, 10))

# %%
df.plot()

# %%
df = pd.DataFrame(np.random.rand(6, 4),index=['1', '2', '3', '4','5', '6'],columns=pd.Index(['A', 'B', 'C', 'D'],name='Genus'))

# %%
data.plot.barh(ax=axes[1], color='k', alpha=0.7)

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='y', alpha=0.5)

# %%
df = pd.DataFrame(np.random.rand(6, 4),index=['1', '2', '3', '4','5', '6'],columns=pd.Index(['x', 'y', 'z', 'w'],name='Genus'))

# %%
df.plot.bar()

# %%
df.plot.barh(stacked=True)

# %%
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')

# %%
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2]))
sns.distplot(values, bins=100, color='y')

# %%
df = pd.DataFrame({'key1' : ['1', '1', '2', '2', '1'],'key2' : ['x', 'y', 'x', 'y', 'x'],'data1' : np.random.randn(5),'data2' : np.random.randn(5)})

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    1    x -0.429159  0.209445
# 1    1    y -0.858265 -0.579000
# 2    2    x -0.425692  1.953970
# 3    2    y  0.684805  0.378773
# 4    1    x -0.825932  0.019253

# %%
grouped = df['data1'].groupby(df['key1']) #访问data1，并根据key1调用groupby：

# %%
grouped

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean() #一次传入多个数组的列表，就会得到不同的结果：
means
# Out:
# key1  key2
# 1     x      -0.627545
#       y      -0.858265
# 2     x      -0.425692
#       y       0.684805
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2         x         y
# key1
# 1    -0.627545 -0.858265
# 2    -0.425692  0.684805

# %%
people = pd.DataFrame(np.random.randn(5, 5),columns=['a', 'b', 'c', 'd', 'e'],index=['Joe', 'Steve', 'Wes', 'Jim','Travis'])
people.iloc[2:3, [1, 2]] = np.nan # Add a few NA values
people
# Out:
#                a         b         c         d         e
# Joe     0.753770 -1.113688  0.625687 -0.329359  2.201586
# Steve   0.111099 -1.936927  0.215251 -0.998374  0.641388
# Wes    -1.394158       NaN       NaN -0.283373  0.268089
# Jim    -0.634018 -1.021122  1.102564 -1.787723  0.554270
# Travis -0.266025 -1.507636  0.930135  0.693541 -0.307455

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue','d': 'blue', 'e': 'red', 'f' : 'orange'}
by_column = people.groupby(mapping, axis=1)
by_column.sum()
# Out:
#             blue       red
# Joe     0.296329  1.841668
# Steve  -0.783123 -1.184441
# Wes    -0.283373 -1.126069
# Jim    -0.685159 -1.100870
# Travis  1.623676 -2.081116

# %%
map_series = pd.Series(mapping)
people.groupby(map_series, axis=1).count()
# Out:
#         blue  red
# Joe        2    3
# Steve      2    3
# Wes        1    2
# Jim        2    3
# Travis     2    3

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3 -1.274405 -2.134811  1.728251 -2.400455  3.023945
# 5  0.111099 -1.936927  0.215251 -0.998374  0.641388
# 6 -0.266025 -1.507636  0.930135  0.693541 -0.307455

# %%
 key_list = ['one', 'one', 'one', 'two', 'two']

# %%
people.groupby([len, key_list]).max()
# Out:
#               a         b         c         d         e
# 3 one  0.753770 -1.113688  0.625687 -0.283373  2.201586
#   two -0.634018 -1.021122  1.102564 -1.787723  0.554270
# 5 one  0.111099 -1.936927  0.215251 -0.998374  0.641388
# 6 two -0.266025 -1.507636  0.930135  0.693541 -0.307455

# %%
columns = pd.MultiIndex.from_arrays([['china', 'china', 'china', 'us','us'],[1, 3, 5, 1, 3]],names=['cty', 'tenor'])
hier_df = pd.DataFrame(np.random.randn(4, 5), columns=columns)
hier_df
# Out:
# cty       china                            us
# tenor         1         3         5         1         3
# 0      1.489570 -0.086192 -0.356078  0.504157 -0.691347
# 1      0.470997  1.051216  0.428907 -0.113150 -1.499144
# 2      1.097122 -1.043122  0.208189  1.717663  0.708477
# 3     -0.269608  0.846349 -0.897989  1.912833  0.262037

# %%
hier_df.groupby(level='cty', axis=1).count()
# Out:
# cty  china  us
# 0        3   2
# 1        3   2
# 2        3   2
# 3        3   2

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    1    x -0.429159  0.209445
# 1    1    y -0.858265 -0.579000
# 2    2    x -0.425692  1.953970
# 3    2    y  0.684805  0.378773
# 4    1    x -0.825932  0.019253

# %%
grouped = df.groupby('key1')

# %%
grouped['data1'].quantile(0.9)
# Out:
# key1
# 1   -0.508513
# 2    0.573755
# Name: data1, dtype: float64

# %%
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# 1      3.0 -0.704452  0.238958 -0.858265 -0.842098 -0.825932 -0.627545
# 2      2.0  0.129556  0.785240 -0.425692 -0.148068  0.129556  0.407181
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# 1    -0.429159   3.0 -0.116767  0.411446 -0.579000 -0.279874  0.019253
# 2     0.684805   2.0  1.166371  1.113832  0.378773  0.772572  1.166371
#
#
#            75%       max
# key1
# 1     0.114349  0.209445
# 2     1.560171  1.953970

# %%
frame = pd.DataFrame({'data1': np.random.randn(100),'data2': np.random.randn(100)})
quartiles = pd.cut(frame.data1, 4)

# %%
quartiles[:20]
# Out:
# 0      (-1.121, 0.303]
# 1      (-1.121, 0.303]
# 2     (-2.551, -1.121]
# 3      (-1.121, 0.303]
# 4      (-1.121, 0.303]
# 5       (0.303, 1.728]
# 6     (-2.551, -1.121]
# 7      (-1.121, 0.303]
# 8       (1.728, 3.152]
# 9       (0.303, 1.728]
# 10      (0.303, 1.728]
# 11      (0.303, 1.728]
# 12      (0.303, 1.728]
# 13      (1.728, 3.152]
# 14     (-1.121, 0.303]
# 15     (-1.121, 0.303]
# 16    (-2.551, -1.121]
# 17    (-2.551, -1.121]
# 18      (0.303, 1.728]
# 19     (-1.121, 0.303]
# Name: data1, dtype: category
# Categories (4, interval[float64]): [(-2.551, -1.121] < (-1.121, 0.303] < (0.303, 1.728] < (1.728, 3.152]]

# %%
def get_stats(group):
    return {'min': group.min(), 'max': group.max(),'count': group.count(), 'mean': group.mean()}
grouped = frame.data2.groupby(quartiles)

# %%
grouped.apply(get_stats).unstack()
# Out:
#                   count       max      mean       min
# data1
# (-2.551, -1.121]   16.0  1.347647  0.077841 -1.943081
# (-1.121, 0.303]    49.0  2.640865 -0.138144 -3.505602
# (0.303, 1.728]     28.0  1.655514  0.037875 -2.328777
# (1.728, 3.152]      7.0  1.133524 -0.646425 -2.893779

# %%
s = pd.Series(np.random.randn(9))
s[::2] = np.nan
s
# Out:
# 0         NaN
# 1    2.799317
# 2         NaN
# 3    0.429864
# 4         NaN
# 5    1.569853
# 6         NaN
# 7   -1.422734
# 8         NaN
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0    0.844075
# 1    2.799317
# 2    0.844075
# 3    0.429864
# 4    0.844075
# 5    1.569853
# 6    0.844075
# 7   -1.422734
# 8    0.844075
# dtype: float64

# %%
states = ['x', 'y', 'z', 'w','r', 'o', 'p', 'q']
group_key = ['East'] * 4 + ['West'] * 4
data = pd.Series(np.random.randn(8), index=states)
data
# Out:
# x   -0.402523
# y   -0.020866
# z    0.211745
# w   -0.181944
# r   -1.159068
# o    1.435438
# p   -1.248024
# q    1.376244
# dtype: float64

# %%
fill_mean = lambda g: g.fillna(g.mean())
data.groupby(group_key).apply(fill_mean)
# Out:
# x   -0.402523
# y   -0.020866
# z    0.211745
# w   -0.181944
# r   -1.159068
# o    1.435438
# p   -1.248024
# q    1.376244
# dtype: float64

# %%
df = pd.DataFrame({'category': ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b'],'data': np.random.randn(8),'weights': np.random.rand(8)})

# %%
df
# Out:
#   category      data   weights
# 0        a -0.026956  0.707856
# 1        a  0.060852  0.822421
# 2        a -0.433688  0.228409
# 3        a -0.524053  0.159907
# 4        b -0.453100  0.449450
# 5        b  0.469692  0.465540
# 6        b  0.600740  0.271032
# 7        b  0.841470  0.812837

# %%
grouped = df.groupby('category')

# %%
get_wavg = lambda g: np.average(g['data'],weights=g['weights'])
grouped.apply(get_wavg)
# Out:
# category
# a   -0.079169
# b    0.431152
# dtype: float64
